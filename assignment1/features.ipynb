# %%
# This mounts your Google Drive to the Colab VM.
# from google.colab import drive
# drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
# FOLDERNAME = None
# assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
# sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd ~/Desktop/ML/CS231n_Stanford/assignment1/cs231n/datasets/
# !bash get_datasets.sh
# %cd ~/Desktop/ML/CS231n_Stanford/assignment1/
# Out:
# /Users/harshitraj/Desktop/ML/CS231n_Stanford/assignment1/cs231n/datasets
# /Users/harshitraj/Desktop/ML/CS231n_Stanford/assignment1

# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 20 # Number of bins in the color histogram ####Was set at 10 initially in assignment
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [3e-6, 1e-5, 3e-5]#[1e-9, 1e-8, 1e-7]
regularization_strengths = [1e5, 3e5, 5e5, 7.5e5, 1e6]#[5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

num_iters = 200

for lr in learning_rates:
    for reg in regularization_strengths:
        svm = None
        svm = LinearSVM()
        svm.train(X_train_feats,y_train,lr,reg,num_iters,verbose=True,lr_decay = 0.97)
        svm.predict
        y_train_pred = svm.predict(X_train_feats)
        y_val_pred = svm.predict(X_val_feats)
        train_accuracy = np.mean(y_train == y_train_pred)
        val_accuracy = np.mean(y_val == y_val_pred)
        results[(lr,reg)] = (train_accuracy,val_accuracy)
        if val_accuracy>best_val:
            best_val = val_accuracy
            best_svm = svm

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved: %f' % best_val)
# Out:
# iteration 0 / 200: loss 173.981499
# iteration 100 / 200: loss 9.000081
# iteration 0 / 200: loss 536.643191
# iteration 100 / 200: loss 9.000002
# iteration 0 / 200: loss 844.153093
# iteration 100 / 200: loss 9.000006
# iteration 0 / 200: loss 1198.081137
# iteration 100 / 200: loss 9.000011
# iteration 0 / 200: loss 1693.253338
# iteration 100 / 200: loss 9.000007
# iteration 0 / 200: loss 179.677769
# iteration 100 / 200: loss 9.000022
# iteration 0 / 200: loss 507.824034
# iteration 100 / 200: loss 9.000008
# iteration 0 / 200: loss 838.239682
# iteration 100 / 200: loss 9.000013
# iteration 0 / 200: loss 1292.390988
# iteration 100 / 200: loss 9.000021
# iteration 0 / 200: loss 1578.115210
# iteration 100 / 200: loss 223660.722140
# iteration 0 / 200: loss 178.388032
# iteration 100 / 200: loss 9.000037
# iteration 0 / 200: loss 499.274599
# iteration 100 / 200: loss 9.000168
# iteration 0 / 200: loss 876.886872
# iteration 100 / 200: loss 7129269955616956647086601956121528787533824.000000
# iteration 0 / 200: loss 1358.531867
# iteration 100 / 200: loss 1853247396747211155518861216883454896530120219335310704451735843526500723338330480342570100964641401208832.000000
# iteration 0 / 200: loss 1617.426222
# iteration 100 / 200: loss 529558952693656756342444362421312652122496158333642562716209652744146405956944214230053202219944160083268264486281496997518464996191543893164032.000000
# lr 3.000000e-06 reg 1.000000e+05 train accuracy: 0.420776 val accuracy: 0.424000
# lr 3.000000e-06 reg 3.000000e+05 train accuracy: 0.421592 val accuracy: 0.428000
# lr 3.000000e-06 reg 5.000000e+05 train accuracy: 0.423490 val accuracy: 0.423000
# lr 3.000000e-06 reg 7.500000e+05 train accuracy: 0.423082 val accuracy: 0.421000
# lr 3.000000e-06 reg 1.000000e+06 train accuracy: 0.418469 val accuracy: 0.419000
# lr 1.000000e-05 reg 1.000000e+05 train accuracy: 0.420367 val accuracy: 0.430000
# lr 1.000000e-05 reg 3.000000e+05 train accuracy: 0.419388 val accuracy: 0.421000
# lr 1.000000e-05 reg 5.000000e+05 train accuracy: 0.417551 val accuracy: 0.412000
# lr 1.000000e-05 reg 7.500000e+05 train accuracy: 0.414551 val accuracy: 0.419000
# lr 1.000000e-05 reg 1.000000e+06 train accuracy: 0.414408 val accuracy: 0.417000
# lr 3.000000e-05 reg 1.000000e+05 train accuracy: 0.419224 val accuracy: 0.418000
# lr 3.000000e-05 reg 3.000000e+05 train accuracy: 0.419408 val accuracy: 0.426000
# lr 3.000000e-05 reg 5.000000e+05 train accuracy: 0.085959 val accuracy: 0.073000
# lr 3.000000e-05 reg 7.500000e+05 train accuracy: 0.108429 val accuracy: 0.121000
# lr 3.000000e-05 reg 1.000000e+06 train accuracy: 0.104367 val accuracy: 0.127000
# best validation accuracy achieved: 0.430000

# %%
# Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.428

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 165)
# (49000, 164)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

data = {
    'X_train': X_train_feats, 
    'y_train': y_train, 
    'X_val': X_val_feats, 
    'y_val': y_val, 
    'X_test': X_test_feats, 
    'y_test': y_test, 
}

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

num_train = y_train.shape[0]
mask = np.random.choice(num_train,num_train//10)
data_small = {
    'X_train': X_train_feats[mask], 
    'y_train': y_train[mask], 
    'X_val': X_val_feats, 
    'y_val': y_val, 
    'X_test': X_test_feats, 
    'y_test': y_test, 
}

learning_rates = [0.18,0.3,0.58,1,1.8,3,5.8] #Best in [1,1.8]

best_lr = 0
best_val = 0
t = len(learning_rates)
for i,lr in enumerate(learning_rates):
    net = None
    net = TwoLayerNet(input_dim, hidden_dim, num_classes, reg=0.005)
    solver = None
    solver = Solver(net,data,optim_config={'learning_rate': lr},
                   print_every=5000,lr_decay=0.9,num_epochs=20)
    solver.train()
    val = solver.best_val_acc
    print('#### LR= {:>3} Best Validation Accuracy= {:>4} ####'.format(lr,val))
    if val>best_val:
        best_val = val
        best_net = net
        best_lr = lr
    print('------------------------Progress= %f%%--------------------------'% (100*(i+1)/t))


        
print('Best-of-Best Validation Accuracy = %f at LR= %f' %(best_val,best_lr))

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# (Iteration 1 / 9800) loss: 2.302768
# (Epoch 0 / 20) train acc: 0.148000; val_acc: 0.137000
# (Epoch 1 / 20) train acc: 0.504000; val_acc: 0.505000
# (Epoch 2 / 20) train acc: 0.560000; val_acc: 0.526000
# (Epoch 3 / 20) train acc: 0.565000; val_acc: 0.541000
# (Epoch 4 / 20) train acc: 0.591000; val_acc: 0.558000
# (Epoch 5 / 20) train acc: 0.623000; val_acc: 0.570000
# (Epoch 6 / 20) train acc: 0.627000; val_acc: 0.586000
# (Epoch 7 / 20) train acc: 0.608000; val_acc: 0.577000
# (Epoch 8 / 20) train acc: 0.617000; val_acc: 0.578000
# (Epoch 9 / 20) train acc: 0.636000; val_acc: 0.597000
# (Epoch 10 / 20) train acc: 0.635000; val_acc: 0.599000
# (Iteration 5001 / 9800) loss: 1.283548
# (Epoch 11 / 20) train acc: 0.632000; val_acc: 0.594000
# (Epoch 12 / 20) train acc: 0.677000; val_acc: 0.596000
# (Epoch 13 / 20) train acc: 0.646000; val_acc: 0.599000
# (Epoch 14 / 20) train acc: 0.667000; val_acc: 0.607000
# (Epoch 15 / 20) train acc: 0.685000; val_acc: 0.605000
# (Epoch 16 / 20) train acc: 0.655000; val_acc: 0.597000
# (Epoch 17 / 20) train acc: 0.645000; val_acc: 0.608000
# (Epoch 18 / 20) train acc: 0.678000; val_acc: 0.607000
# (Epoch 19 / 20) train acc: 0.656000; val_acc: 0.609000
# (Epoch 20 / 20) train acc: 0.659000; val_acc: 0.614000
# #### LR= 0.18 Best Validation Accuracy= 0.614 ####
# ------------------------Progress= 14.285714%--------------------------
# (Iteration 1 / 9800) loss: 2.302781
# (Epoch 0 / 20) train acc: 0.104000; val_acc: 0.079000
# (Epoch 1 / 20) train acc: 0.545000; val_acc: 0.526000
# (Epoch 2 / 20) train acc: 0.550000; val_acc: 0.537000
# (Epoch 3 / 20) train acc: 0.551000; val_acc: 0.549000
# (Epoch 4 / 20) train acc: 0.605000; val_acc: 0.568000
# (Epoch 5 / 20) train acc: 0.609000; val_acc: 0.564000
# (Epoch 6 / 20) train acc: 0.644000; val_acc: 0.584000
# (Epoch 7 / 20) train acc: 0.631000; val_acc: 0.589000
# (Epoch 8 / 20) train acc: 0.641000; val_acc: 0.614000
# (Epoch 9 / 20) train acc: 0.654000; val_acc: 0.586000
# (Epoch 10 / 20) train acc: 0.655000; val_acc: 0.592000
# (Iteration 5001 / 9800) loss: 1.281215
# (Epoch 11 / 20) train acc: 0.682000; val_acc: 0.602000
# (Epoch 12 / 20) train acc: 0.649000; val_acc: 0.605000
# (Epoch 13 / 20) train acc: 0.673000; val_acc: 0.620000
# (Epoch 14 / 20) train acc: 0.657000; val_acc: 0.613000
# (Epoch 15 / 20) train acc: 0.661000; val_acc: 0.601000
# (Epoch 16 / 20) train acc: 0.666000; val_acc: 0.613000
# (Epoch 17 / 20) train acc: 0.663000; val_acc: 0.617000
# (Epoch 18 / 20) train acc: 0.704000; val_acc: 0.613000
# (Epoch 19 / 20) train acc: 0.674000; val_acc: 0.618000
# (Epoch 20 / 20) train acc: 0.699000; val_acc: 0.610000
# #### LR= 0.3 Best Validation Accuracy= 0.62 ####
# ------------------------Progress= 28.571429%--------------------------
# (Iteration 1 / 9800) loss: 2.302797
# (Epoch 0 / 20) train acc: 0.089000; val_acc: 0.078000
# (Epoch 1 / 20) train acc: 0.517000; val_acc: 0.498000
# (Epoch 2 / 20) train acc: 0.554000; val_acc: 0.542000
# (Epoch 3 / 20) train acc: 0.585000; val_acc: 0.549000
# (Epoch 4 / 20) train acc: 0.603000; val_acc: 0.558000
# (Epoch 5 / 20) train acc: 0.618000; val_acc: 0.564000
# (Epoch 6 / 20) train acc: 0.615000; val_acc: 0.581000
# (Epoch 7 / 20) train acc: 0.604000; val_acc: 0.572000
# (Epoch 8 / 20) train acc: 0.639000; val_acc: 0.592000
# (Epoch 9 / 20) train acc: 0.628000; val_acc: 0.591000
# (Epoch 10 / 20) train acc: 0.672000; val_acc: 0.592000
# (Iteration 5001 / 9800) loss: 1.199880
# (Epoch 11 / 20) train acc: 0.653000; val_acc: 0.583000
# (Epoch 12 / 20) train acc: 0.664000; val_acc: 0.576000
# (Epoch 13 / 20) train acc: 0.656000; val_acc: 0.607000
# (Epoch 14 / 20) train acc: 0.665000; val_acc: 0.592000
# (Epoch 15 / 20) train acc: 0.662000; val_acc: 0.596000
# (Epoch 16 / 20) train acc: 0.670000; val_acc: 0.597000
# (Epoch 17 / 20) train acc: 0.668000; val_acc: 0.608000
# (Epoch 18 / 20) train acc: 0.678000; val_acc: 0.593000
# (Epoch 19 / 20) train acc: 0.697000; val_acc: 0.611000
# (Epoch 20 / 20) train acc: 0.678000; val_acc: 0.603000
# #### LR= 0.58 Best Validation Accuracy= 0.611 ####
# ------------------------Progress= 42.857143%--------------------------
# (Iteration 1 / 9800) loss: 2.302820
# (Epoch 0 / 20) train acc: 0.096000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.498000; val_acc: 0.501000
# (Epoch 2 / 20) train acc: 0.562000; val_acc: 0.511000
# (Epoch 3 / 20) train acc: 0.566000; val_acc: 0.544000
# (Epoch 4 / 20) train acc: 0.591000; val_acc: 0.545000
# (Epoch 5 / 20) train acc: 0.570000; val_acc: 0.539000
# (Epoch 6 / 20) train acc: 0.554000; val_acc: 0.528000
# (Epoch 7 / 20) train acc: 0.603000; val_acc: 0.555000
# (Epoch 8 / 20) train acc: 0.602000; val_acc: 0.565000
# (Epoch 9 / 20) train acc: 0.598000; val_acc: 0.567000
# (Epoch 10 / 20) train acc: 0.597000; val_acc: 0.569000
# (Iteration 5001 / 9800) loss: 1.359643
# (Epoch 11 / 20) train acc: 0.619000; val_acc: 0.576000
# (Epoch 12 / 20) train acc: 0.629000; val_acc: 0.558000
# (Epoch 13 / 20) train acc: 0.629000; val_acc: 0.562000
# (Epoch 14 / 20) train acc: 0.660000; val_acc: 0.601000
# (Epoch 15 / 20) train acc: 0.648000; val_acc: 0.585000
# (Epoch 16 / 20) train acc: 0.643000; val_acc: 0.586000
# (Epoch 17 / 20) train acc: 0.645000; val_acc: 0.603000
# (Epoch 18 / 20) train acc: 0.670000; val_acc: 0.579000
# (Epoch 19 / 20) train acc: 0.664000; val_acc: 0.602000
# (Epoch 20 / 20) train acc: 0.663000; val_acc: 0.611000
# #### LR=   1 Best Validation Accuracy= 0.611 ####
# ------------------------Progress= 57.142857%--------------------------
# (Iteration 1 / 9800) loss: 2.302811
# (Epoch 0 / 20) train acc: 0.109000; val_acc: 0.102000
# (Epoch 1 / 20) train acc: 0.488000; val_acc: 0.437000
# (Epoch 2 / 20) train acc: 0.484000; val_acc: 0.460000
# (Epoch 3 / 20) train acc: 0.493000; val_acc: 0.495000
# (Epoch 4 / 20) train acc: 0.522000; val_acc: 0.497000
# (Epoch 5 / 20) train acc: 0.546000; val_acc: 0.496000
# (Epoch 6 / 20) train acc: 0.552000; val_acc: 0.526000
# (Epoch 7 / 20) train acc: 0.575000; val_acc: 0.519000
# (Epoch 8 / 20) train acc: 0.565000; val_acc: 0.549000
# (Epoch 9 / 20) train acc: 0.572000; val_acc: 0.516000
# (Epoch 10 / 20) train acc: 0.569000; val_acc: 0.542000
# (Iteration 5001 / 9800) loss: 1.573848
# (Epoch 11 / 20) train acc: 0.586000; val_acc: 0.552000
# (Epoch 12 / 20) train acc: 0.582000; val_acc: 0.549000
# (Epoch 13 / 20) train acc: 0.620000; val_acc: 0.559000
# (Epoch 14 / 20) train acc: 0.605000; val_acc: 0.550000
# (Epoch 15 / 20) train acc: 0.618000; val_acc: 0.561000
# (Epoch 16 / 20) train acc: 0.614000; val_acc: 0.571000
# (Epoch 17 / 20) train acc: 0.616000; val_acc: 0.565000
# (Epoch 18 / 20) train acc: 0.645000; val_acc: 0.584000
# (Epoch 19 / 20) train acc: 0.641000; val_acc: 0.582000
# (Epoch 20 / 20) train acc: 0.596000; val_acc: 0.599000
# #### LR= 1.8 Best Validation Accuracy= 0.599 ####
# ------------------------Progress= 71.428571%--------------------------
# (Iteration 1 / 9800) loss: 2.302798
# (Epoch 0 / 20) train acc: 0.096000; val_acc: 0.102000
# (Epoch 1 / 20) train acc: 0.341000; val_acc: 0.333000
# (Epoch 2 / 20) train acc: 0.341000; val_acc: 0.377000
# (Epoch 3 / 20) train acc: 0.414000; val_acc: 0.414000
# (Epoch 4 / 20) train acc: 0.414000; val_acc: 0.407000
# (Epoch 5 / 20) train acc: 0.454000; val_acc: 0.422000
# (Epoch 6 / 20) train acc: 0.415000; val_acc: 0.458000
# (Epoch 7 / 20) train acc: 0.459000; val_acc: 0.472000
# (Epoch 8 / 20) train acc: 0.488000; val_acc: 0.460000
# (Epoch 9 / 20) train acc: 0.486000; val_acc: 0.486000
# (Epoch 10 / 20) train acc: 0.493000; val_acc: 0.449000
# (Iteration 5001 / 9800) loss: 1.477454
# (Epoch 11 / 20) train acc: 0.497000; val_acc: 0.495000
# (Epoch 12 / 20) train acc: 0.456000; val_acc: 0.483000
# (Epoch 13 / 20) train acc: 0.555000; val_acc: 0.512000
# (Epoch 14 / 20) train acc: 0.551000; val_acc: 0.503000
# (Epoch 15 / 20) train acc: 0.509000; val_acc: 0.488000
# (Epoch 16 / 20) train acc: 0.541000; val_acc: 0.515000
# (Epoch 17 / 20) train acc: 0.534000; val_acc: 0.528000
# (Epoch 18 / 20) train acc: 0.534000; val_acc: 0.524000
# (Epoch 19 / 20) train acc: 0.542000; val_acc: 0.515000
# (Epoch 20 / 20) train acc: 0.542000; val_acc: 0.533000
# #### LR=   3 Best Validation Accuracy= 0.533 ####
# ------------------------Progress= 85.714286%--------------------------
# (Iteration 1 / 9800) loss: 2.302797
# (Epoch 0 / 20) train acc: 0.143000; val_acc: 0.149000
# (Epoch 1 / 20) train acc: 0.083000; val_acc: 0.087000
# (Epoch 2 / 20) train acc: 0.096000; val_acc: 0.087000
# (Epoch 3 / 20) train acc: 0.108000; val_acc: 0.087000
# (Epoch 4 / 20) train acc: 0.099000; val_acc: 0.087000
# (Epoch 5 / 20) train acc: 0.099000; val_acc: 0.087000
# (Epoch 6 / 20) train acc: 0.090000; val_acc: 0.087000
# (Epoch 7 / 20) train acc: 0.112000; val_acc: 0.087000
# (Epoch 8 / 20) train acc: 0.099000; val_acc: 0.087000
# (Epoch 9 / 20) train acc: 0.096000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.086000; val_acc: 0.087000
# (Iteration 5001 / 9800) loss: nan
# (Epoch 11 / 20) train acc: 0.094000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.112000; val_acc: 0.087000
# (Epoch 13 / 20) train acc: 0.082000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.103000; val_acc: 0.087000
# (Epoch 15 / 20) train acc: 0.099000; val_acc: 0.087000
# (Epoch 16 / 20) train acc: 0.088000; val_acc: 0.087000
# (Epoch 17 / 20) train acc: 0.113000; val_acc: 0.087000
# (Epoch 18 / 20) train acc: 0.097000; val_acc: 0.087000
# (Epoch 19 / 20) train acc: 0.095000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.094000; val_acc: 0.087000
# #### LR= 5.8 Best Validation Accuracy= 0.149 ####
# ------------------------Progress= 100.000000%--------------------------
# Best-of-Best Validation Accuracy = 0.620000 at LR= 0.300000

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.562
